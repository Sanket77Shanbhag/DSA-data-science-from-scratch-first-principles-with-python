# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import adjusted_rand_score
from scipy.cluster.hierarchy import dendrogram, linkage

data = np.loadtxt('Spiral.txt')

X = data[:, :2]
true_labels = data[:, 2].astype(int)

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=true_labels, cmap='viridis', edgecolor='k', s=50)
plt.title('True Clusters')
plt.xlabel('X1')
plt.ylabel('X2')
plt.colorbar()
plt.show()
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_pred = kmeans.fit_predict(X)

rand_index_kmeans = adjusted_rand_score(true_labels, kmeans_pred)
print(f"Rand Index for K-means clustering: {rand_index_kmeans:.4f}")

single_linkage = AgglomerativeClustering(n_clusters=3, linkage='single')
single_pred = single_linkage.fit_predict(X)

rand_index_single = adjusted_rand_score(true_labels, single_pred)
print(f"Rand Index for Single-link Hierarchical clustering: {rand_index_single:.4f}")

complete_linkage = AgglomerativeClustering(n_clusters=3, linkage='complete')
complete_pred = complete_linkage.fit_predict(X)

rand_index_complete = adjusted_rand_score(true_labelllllll.s, complete_pred)
print(f"Rand Index for Complete-link Hierarchical clustering: {rand_index_complete:.4f}")
linkage_matrix = linkage(X, method='complete')
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Rand Index for K-means clustering: -0.0060
# Rand Index for Single-link Hierarchical clustering: 1.0000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      31 complete_linkage = AgglomerativeClustering(n_clusters=3, linkage='complete')
#      32 complete_pred = complete_linkage.fit_predict(X)
# ---> 34 rand_index_complete = adjusted_rand_score(true_labelllllll.s, complete_pred)
#      35 print(f"Rand Index for Complete-link Hierarchical clustering: {rand_index_complete:.4f}")
#      36 linkage_matrix = linkage(X, method='complete')
#
# NameError: name 'true_labelllllll' is not defined
